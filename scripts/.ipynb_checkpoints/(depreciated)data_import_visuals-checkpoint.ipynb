# %%
import sys
# !pip install numpy
# !pip install matplotlib
# !pip install torch
# !pip install pandas
# !pip install sklearn
# !pip install itertools

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import pandas as pd
import sklearn as sk
import itertools
from datetime import datetime, time

print('imports succesfull')
# Out:
# imports succesfull

# %%
# Defining functions for later reuse

# importing data
def import_csv(data_path):
    df = pd.read_csv(data_path)
    # print(df)

    return df


def import_csv_filt(data_path : str, start_date : str, end_date : str, ewma = False) -> pd.DataFrame: 
    """ This function loads the data, filters on the given time window and filters and fills outliers with the group (5) avarage.  """
    
    
    df = pd.read_csv(data_path)
    df_filt = df[(df['time'] > start_date) & (df['time'] < end_date)] 
    
    return df_filt
    
    



data_path_temp = '../data/[test_data]_dashboard_temperatures_2022-08-06T00-00-00_2022-09-04T23-59-59 - kopie.csv'
data_path_motor = '../data/[test_data]_dashboard_motor-data_2022-08-08T00-00-00_2022-09-06T23-59-59.csv'



df = import_csv(data_path_temp)
df_m = import_csv(data_path_motor)

# NORMALISE THE DATA

print(df)
print(df_m)

# df = pd.concat([df_m,df_t], axis=1)

# print(df)

idx_filt = (df['HZ1'] < 300) & (df['HZ2'] < 300) & (df['HZ3'] < 300) & (df['HZ4'] < 300)
df_filt = df[idx_filt]

HZs = ['HZ1', 'HZ2', 'HZ3', 'HZ4']

for hz in HZs:
    plt.plot(df_filt[hz])

plt.show()
# Out:
#                         time     HZ1     HZ2     HZ3     HZ4
# 0    2022-09-02 15:50:24.000   34.58   36.16   36.38   35.18
# 1    2022-09-02 14:24:00.000   38.20   40.70   41.20   39.40
# 2    2022-09-02 12:57:36.000   60.81   69.69   70.91   64.20
# 3    2022-09-02 11:31:12.000  154.62  188.39  195.75  175.44
# 4    2022-09-02 10:04:48.000   49.31   39.04   56.93   38.50
# ..                       ...     ...     ...     ...     ...
# 221  2022-08-06 05:45:36.000   24.24   24.44   24.44   24.24
# 222  2022-08-06 04:19:12.000   26.74   27.36   27.44   26.94
# 223  2022-08-06 02:52:48.000   32.87   34.77   34.97   33.57
# 224  2022-08-06 01:26:24.000   51.30   57.58   58.59   54.57
# 225  2022-08-06 00:00:00.000  121.75  143.97  145.71  129.84
#
# [226 rows x 5 columns]
#                         time  Screw Torque  Screw RPM  Servo Utilization  \
# 0    2022-09-05 10:33:36.000          -0.0        0.0               0.00
# 1    2022-09-02 16:19:12.000           0.0        0.0               0.01
# 2    2022-09-02 14:52:48.000           0.0        0.0               0.01
# 3    2022-09-02 13:26:24.000           0.0        0.0               0.01
# 4    2022-09-02 12:00:00.000           0.0        0.0               0.05
# ..                       ...           ...        ...                ...
# 211  2022-08-08 14:24:00.000          15.0       12.0               4.46
# 212  2022-08-08 12:57:36.000          15.0       12.0               5.13
# 213  2022-08-08 11:31:12.000           3.0       25.0              15.26
# 214  2022-08-08 10:04:48.000          19.0       76.0              20.34
# 215  2022-08-08 08:38:24.000          -0.0        0.0               0.00
#
#      Torque%
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 211       16
# 212       16
# 213        3
# 214       20
# 215        0
#
# [216 rows x 5 columns]

# %%
# motor_values = ['Screw Torque', 'Torque%']

# for mv in motor_values:
#     plt.plot(df_filt[mv])

# plt.show()

# %%
# importing data
# preprocessing data
## only use those points that have e.g. t amount of time also in front of it
## get number of missing data points
# split train/test data
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df_m, test_size=0.2, shuffle=False)  # do not use shuffle!! Needs to be in timely order. Or do we need to shuffle to a certain degree, whilst keeping the order
# of the previous x data points intact? Or can we do that using indexes??
# OR make new dataset using collumns for every t-1 t-2 ... t-x datapoints for HZ and RPM/torque? -> idea: better intergrateable using existing regression models. 

print(train_set)
# Out:
#                         time  Screw Torque  Screw RPM  Servo Utilization  \
# 0    2022-09-05 10:33:36.000          -0.0        0.0               0.00
# 1    2022-09-02 16:19:12.000           0.0        0.0               0.01
# 2    2022-09-02 14:52:48.000           0.0        0.0               0.01
# 3    2022-09-02 13:26:24.000           0.0        0.0               0.01
# 4    2022-09-02 12:00:00.000           0.0        0.0               0.05
# ..                       ...           ...        ...                ...
# 167  2022-08-11 21:36:00.000          18.0        0.0               6.18
# 168  2022-08-11 20:09:36.000          18.0        0.0               6.18
# 169  2022-08-11 18:43:12.000          18.0        0.0               6.18
# 170  2022-08-11 17:16:48.000          18.0        0.0               6.18
# 171  2022-08-11 15:50:24.000          18.0        0.0               6.18
#
#      Torque%
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 167       19
# 168       19
# 169       19
# 170       19
# 171       19
#
# [172 rows x 5 columns]

# %%
# models to be used for the regression task
# Linear Regression 
from sklearn.linear_model import LinearRegression

# Decision Trees
from sklearn.tree import DecisionTreeRegressor

# Random Forest
from sklearn.ensemble import RandomForestRegressor

# maybe a polynomial regression? see p.129 of book. 
from sklearn.preprocessing import PolynomialFeatures

# or SVM regression? see p.162 of the book.

# %%
# get a learning curve of the models! check p. 132 of book
from sklearn.metrics import mean_squared_error

# %%
lst = [ 60, 70, 80, 90]

for subset in itertools.combinations(range(6, 10), 2):
    print( ' '.join(str(subset)))
# Out:
# ( 6 ,   7 )
# ( 6 ,   8 )
# ( 6 ,   9 )
# ( 7 ,   8 )
# ( 7 ,   9 )
# ( 8 ,   9 )

# %%
permus = []

for indices in itertools.permutations(lst, 2):
    print(indices)
    permus.append(indices)
    
print(permus)
# Out:
# (60, 70)
# (60, 80)
# (60, 90)
# (70, 60)
# (70, 80)
# (70, 90)
# (80, 60)
# (80, 70)
# (80, 90)
# (90, 60)
# (90, 70)
# (90, 80)
# [(60, 70), (60, 80), (60, 90), (70, 60), (70, 80), (70, 90), (80, 60), (80, 70), (80, 90), (90, 60), (90, 70), (90, 80)]

# %%
# loading test dataframe
test_dataset_loc = '../data/data_test_wo_rollers_23-09-12.21.00--12.25.00.csv'
df_test_wo_rollers = import_csv(test_dataset_loc) 

# defining start and end times (strings)
start_date_str = '2022-09-23 12:21:00.000'
end_date_str = '2022-09-23 12:25:00.000'
# defining start and end times in datetime (not strictly nesecairy (, yet))
start_date = datetime.strptime(start_date_str, '%Y-%m-%d %H:%M:%S.%f')
end_date = datetime.strptime(end_date_str, '%Y-%m-%d %H:%M:%S.%f')

# use function to get dataset
df_test_filt = import_csv_filt(test_dataset_loc, start_date_str, end_date_str)

# plot with outliers
plt.plot(df_test_filt['bead_width (mm)'])
plt.show()

something = (df_test_filt['bead_width (mm)'] - df_test_filt['bead_width (mm)'].rolling(10).median()).abs() > 2

print(something)

for i, some in enumerate(something):
    if some == True:
        print(f'true, location = {i + 202}')

##### TO DO:#####
""" 
* make function to import datasets
* append a function to filter on date/time
* outlier detection on the average 10 datapoint or so (more dificutlt)
* start with ML !!! 


"""
# Out:
# 202     False
# 203     False
# 204     False
# 205     False
# 206     False
#         ...
# 1397    False
# 1398    False
# 1399    False
# 1400    False
# 1401    False
# Name: bead_width (mm), Length: 1200, dtype: bool
# true, location = 368
# true, location = 422
# true, location = 869
# true, location = 922
# true, location = 923
# true, location = 1369
# ' \n* make function to import datasets\n* append a function to filter on date/time\n* outlier detection on the average 10 datapoint or so (more dificutlt)\n* start with ML !!! \n\n\n'
